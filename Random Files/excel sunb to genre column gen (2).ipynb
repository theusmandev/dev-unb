# %%
# !pip uninstall -y google-generativeai
# !pip install -U google-genai
# Out:
# WARNING: Skipping google-generativeai as it is not installed.
# ...

# %%
import pandas as pd
from google import genai
from google.colab import files
import time
from tqdm.notebook import tqdm

# 1. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 2. Gemini API Setup (Naya tareeqa)
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI"
client = genai.Client(api_key=API_KEY)

# 3. Data Load karein
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig')
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 4. Genre find karne ka function
def get_novel_genre(title):
    if pd.isna(title) or str(title).strip() == "":
        return "N/A"
    try:
        # Note: Model name mein 'models/' nahi likhna sirf naam likhna hai
        prompt = f"Identify the genre of this Urdu novel based on its title: '{title}'. Just give me the genre name (e.g., Romantic, Social, Mystery, Islamic)."

        response = client.models.generate_content(
            model='gemini-1.5-flash',
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        # Agar koi technical masla ho toh error print ho
        print(f"Error for {title}: {e}")
        return "Unknown"

# 5. Processing with Progress Bar
print("\nProcessing novels... Please wait.")
genres = []
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Fetching Genres"):
    genre = get_novel_genre(row[column_name])
    genres.append(genre)
    # Free API ke liye 4 seconds gap zaroori hai
    time.sleep(4)

# 6. Save and Download
df['Genre'] = genres
output_file = 'stable_novel_bank.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"\nDone! File '{output_file}' ready hai.")
files.download(output_file)
# Out:
# Apni CSV file select karein:
#      <input type="file" id="files-dbbc5c93-b513-43f7-b23d-ec3e2434cac4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbbc5c93-b513-43f7-b23d-ec3e2434cac4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# =========================================
# ONE FILE | ONE CELL | FINAL WORKING CODE
# =========================================

# ---- Install compatible versions (Colab safe) ----
# !pip install -q google-genai tqdm

# ---- Imports ----
import pandas as pd
import time
from tqdm.notebook import tqdm
from google.colab import files
from google import genai

# ---- Upload CSV ----
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# ---- Gemini API Setup ----
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI"  # 🔴 yahan apni key paste karein

client = genai.Client(api_key=API_KEY)

# ✅ GUARANTEED WORKING MODEL
MODEL_NAME = "gemini-1.0-pro"

# ---- Load CSV ----
try:
    df = pd.read_csv(file_name, encoding="utf-8-sig")
except:
    df = pd.read_csv(file_name, encoding="latin1")

column_name = "Titles" if "Titles" in df.columns else df.columns[0]

# ---- Genre Detection Function ----
def get_novel_genre(title):
    if pd.isna(title) or str(title).strip() == "":
        return "N/A"

    prompt = f"""
    Identify the genre of this Urdu novel based ONLY on its title.

    Title: "{title}"

    Reply with ONE word only from:
    Romantic, Social, Mystery, Islamic, Horror, Thriller, Historical
    """

    try:
        response = client.models.generate_content(
            model=MODEL_NAME,
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        print(f"Error for '{title}': {e}")
        return "Unknown"

# ---- Process CSV ----
print("\nProcessing novels... Please wait ⏳")

genres = []

for title in tqdm(df[column_name], desc="Fetching Genres"):
    genres.append(get_novel_genre(title))
    time.sleep(1.2)  # safe delay

# ---- Save & Download ----
df["Genre"] = genres
output_file = "final_novel_bank.csv"
df.to_csv(output_file, index=False, encoding="utf-8-sig")

print("\n✅ Done! File download ho rahi hai...")
files.download(output_file)
# Out:
# Apni CSV file select karein:
#      <input type="file" id="files-794ae8c7-a5b5-4379-a6a4-ab849b733934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-794ae8c7-a5b5-4379-a6a4-ab849b733934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# 1. Sabse pehle zaroori libraries install karein
# !pip install -q -U google-generativeai tqdm

import pandas as pd
import google.generativeai as genai
from google.colab import files
import time
from tqdm.notebook import tqdm

# 2. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 3. Gemini API Setup (Standard Library)
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI" # Apni key yahan dalein
genai.configure(api_key=API_KEY)

# Sahi model name: 'gemini-1.5-flash' (Ye sabse fast aur stable hai)
model = genai.GenerativeModel('gemini-1.5-flash')

# 4. Data Load karein
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig')
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 5. Genre find karne ka function
def get_novel_genre(title):
    if pd.isna(title) or str(title).strip() == "":
        return "N/A"
    try:
        prompt = f"Identify the genre of this Urdu novel based on its title: '{title}'. Just give me the genre name (e.g., Romantic, Social, Mystery, Islamic)."

        # API call
        response = model.generate_content(prompt)
        return response.text.strip()
    except Exception as e:
        # Agar koi error aye toh yahan print hoga
        print(f"\nError for '{title}': {str(e)}")
        return "Unknown"

# 6. Processing with Progress Bar
print("\nProcessing novels... Please wait.")
genres = []
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Fetching Genres"):
    genre = get_novel_genre(row[column_name])
    genres.append(genre)

    # Rate limit (429 error) se bachne ke liye delay
    time.sleep(2)

# 7. Save and Download
df['Genre'] = genres
output_file = 'final_novel_bank.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"\nDone! File '{output_file}' download ho rahi hai.")
files.download(output_file)
# Out:
# Apni CSV file select karein:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
#      <input type="file" id="files-7d0a7998-f70a-4d5c-9b9a-299cc5c4c625" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d0a7998-f70a-4d5c-9b9a-299cc5c4c625">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# ...

# %%
# !pip install -U google-genai

# %%
import pandas as pd
from google import genai
from google.colab import files
import time

# 1. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 2. Gemini API Setup
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI" # Apni key yahan dalein
client = genai.Client(api_key=API_KEY)

# 3. Data Load karein (Encoding fix ke saath)
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig') # Excel files ke liye behtar hai
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 4. Genre find karne ka function
def get_novel_genre(title):
    try:
        prompt = f"Identify the genre of this Urdu novel based on its title: '{title}'. Just give me the genre name (e.g., Romantic, Social, Mystery, Islamic)."
        response = client.models.generate_content(
            model="gemini-1.5-flash",
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        return "Unknown"

# 5. Processing
print("Processing novels...")
genres = []

# Column ka sahi naam check karne ke liye (Titles ya Title)
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

for index, row in df.iterrows():
    genre = get_novel_genre(row[column_name])
    genres.append(genre)
    print(f"Processed: {row[column_name]} -> {genre}")
    time.sleep(1)

# 6. Save and Download
df['Genre'] = genres
output_file = 'updated_novel_bank.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig') # Urdu characters ke liye utf-8-sig zaroori hai

print(f"\nDone! File save ho gayi hai.")
files.download(output_file)
# Out:
# Apni CSV file select karein:
#      <input type="file" id="files-0a4b32a0-3f23-4b7d-8574-4e987fd7460c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a4b32a0-3f23-4b7d-8574-4e987fd7460c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
from google import genai
from google.colab import files
import time
from tqdm.notebook import tqdm  # Progress bar ke liye

# 1. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 2. Gemini API Setup
API_KEY = "YOUR_API_KEY_HERE" # Apni key yahan dalein
client = genai.Client(api_key=API_KEY)

# 3. Data Load karein (Encoding fix ke saath)
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig')
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 4. Genre find karne ka function
def get_novel_genre(title):
    try:
        prompt = f"Identify the genre of this Urdu novel based on its title: '{title}'. Just give me the genre name (e.g., Romantic, Social, Mystery, Islamic)."
        response = client.models.generate_content(
            model="gemini-1.5-flash",
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        return "Unknown"

# 5. Processing with Progress Bar
print("\nProcessing novels... Nazar rakhein niche di gayi progress bar par:")
genres = []
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

# tqdm(df.iterrows(), total=df.shape[0]) progress bar dikhaye ga
for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Fetching Genres"):
    genre = get_novel_genre(row[column_name])
    genres.append(genre)
    # Print line ko tqdm ke saath use karne ke liye tqdm.write istemal karna behtar hai
    # tqdm.write(f"Processed: {row[column_name]} -> {genre}")
    time.sleep(1)

# 6. Save and Download
df['Genre'] = genres
output_file = 'updated_novel_bank_with_progress.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"\nDone! File '{output_file}' save ho gayi hai.")
files.download(output_file)
# Out:
# Apni CSV file select karein:
#      <input type="file" id="files-8deb3c20-2370-4e7e-998e-0c7ce8a08810" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8deb3c20-2370-4e7e-998e-0c7ce8a08810">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
from google import genai
from google.colab import files
import time
from tqdm.notebook import tqdm

# 1. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 2. Gemini API Setup
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI"
client = genai.Client(api_key=API_KEY)

# 3. Data Load
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig')
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 4. Genre function with Error Detail
def get_novel_genre(title):
    if pd.isna(title) or str(title).strip() == "":
        return "Empty Title"
    try:
        prompt = f"Identify the genre of this Urdu novel: '{title}'. Just give the genre name."
        response = client.models.generate_content(
            model="gemini-1.5-flash",
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        # Error print karein taake pata chale 'Unknown' kyun aa raha hai
        print(f"\nError for '{title}': {str(e)}")
        return "Unknown (Check Console)"

# 5. Processing (Wait time barha diya gaya hai)
print("\nProcessing... Agar 'Unknown' aye toh console mein error message dekhein:")
genres = []
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Fetching Genres"):
    genre = get_novel_genre(row[column_name])
    genres.append(genre)
    # 4 seconds delay taake 15 requests per minute ki limit cross na ho
    time.sleep(4)

# 6. Save
df['Genre'] = genres
output_file = 'fixed_novel_bank.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')
files.download(output_file)
# Out:
# Apni CSV file select karein:
#      <input type="file" id="files-3948ead6-080d-4467-aa12-85e3ee1909ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3948ead6-080d-4467-aa12-85e3ee1909ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Sabse pehle ye line run karein taake library update ho jaye
# !pip install -U google-genai

import pandas as pd
from google import genai
from google.colab import files
import time
from tqdm.notebook import tqdm

# 1. File Upload
print("Apni CSV file select karein:")
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# 2. Gemini API Setup
# Note: Apni API Key yahan dalein
API_KEY = "AIzaSyC2eENzubKgXm_p4tqhUPvvbTg2eEBkAJI"
client = genai.Client(api_key=API_KEY)

# 3. Data Load
try:
    df = pd.read_csv(file_name, encoding='utf-8-sig')
except:
    df = pd.read_csv(file_name, encoding='latin1')

# 4. Genre function (Updated Model Name)
def get_novel_genre(title):
    if pd.isna(title) or str(title).strip() == "":
        return "Empty Title"
    try:
        # Humne yahan model ka naam "gemini-1.5-flash" rakha hai
        # Agar ye phir bhi error de toh "gemini-1.5-flash" ki jagah "gemini-2.0-flash" likh dein
        prompt = f"Identify the genre of this Urdu novel based on its title: '{title}'. Just give me the genre name (e.g., Romantic, Social, Mystery, Islamic)."

        response = client.models.generate_content(
            model="gemini-2-flash",
            contents=prompt
        )
        return response.text.strip()
    except Exception as e:
        # Agar 404 aye toh ye line print hogi
        print(f"\nError for '{title}': {str(e)}")
        return "Unknown"

# 5. Processing
print("\nProcessing novels...")
genres = []
column_name = 'Titles' if 'Titles' in df.columns else df.columns[0]

for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Fetching Genres"):
    genre = get_novel_genre(row[column_name])
    genres.append(genre)
    # 4 seconds delay taake 'Too Many Requests' ka error na aye
    time.sleep(4)

# 6. Save and Download
df['Genre'] = genres
output_file = 'updated_novel_bank_fixed.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"\nDone! File '{output_file}' ready hai.")
files.download(output_file)
# Out:
# ...
# Apni CSV file select karein:
#      <input type="file" id="files-dfd8ae11-7cd5-40dc-9fa4-8739c6901552" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfd8ae11-7cd5-40dc-9fa4-8739c6901552">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
