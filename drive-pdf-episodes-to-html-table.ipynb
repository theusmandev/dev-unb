# %% [markdown]
# font change to arial

# %%
from IPython.display import HTML, display

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    html_start = f'''<div class="ep-container" style="font-family: Arial, sans-serif;">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px; font-family: Arial, sans-serif;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title" style="font-family: Arial, sans-serif;">{title} — Episodes</div>
      <div class="ep-sub" style="font-family: Arial, sans-serif;">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569; font-family: Arial, sans-serif;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table" style="font-family: Arial, sans-serif;">
    <thead>
      <tr>
        <th style="font-family: Arial, sans-serif;">Read Episodes Online</th>
        <th style="font-family: Arial, sans-serif;">Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in episodes_dict.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td style="font-family: Arial, sans-serif;"><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download" style="font-family: Arial, sans-serif;"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code (Font changed to Arial)</h3>
    <textarea id="final_code" style="width:100%;height:300px; font-family: Arial, sans-serif;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray; font-family: Arial, sans-serif;">You can paste this directly into your Blogger post HTML view. Ab poora table Arial font mein display hoga.</p>
    """))


# === 🔹 Example usage ===
episodes = {
    1: "https://drive.google.com/file/d/1wbx-OhKSoFnvlwPAK0yj1xVfqXqJZWCi/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1yzlEAQLghx1DaBhsTqHE6hObl13qtBkt/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1sJ7s98EkMxLOIGdPgkLJz7-kxunXYpFL/view?usp=drive_link",
    4: "https://drive.google.com/file/d/1nankaln6666hsOt-GM3zz24_w1v-f0nc/view?usp=drive_link",
}

generate_episode_table(episodes, title="Mahe Darakhshan")
# Out:
#     <h3>✅ Generated HTML Table Code (Font changed to Arial)</h3>
#     <textarea id="final_code" style="width:100%;height:300px; font-family: Arial, sans-serif;"><div class="ep-container" style="font-family: Arial, sans-serif;">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px; font-family: Arial, sans-serif;">Mahe Darakhshan — All Episodes (1–4)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title" style="font-family: Arial, sans-serif;">Mahe Darakhshan — Episodes</div>
#       <div class="ep-sub" style="font-family: Arial, sans-serif;">4 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569; font-family: Arial, sans-serif;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table" style="font-family: Arial, sans-serif;">
#     <thead>
#       <tr>
# ...

# %%
<tr>
<td><b>Episode 8</b></td>
<td><b>Coming Soon</b></td>
</tr>

# %%
from IPython.display import HTML, display

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in episodes_dict.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {
    1: "https://drive.google.com/file/d/1wbx-OhKSoFnvlwPAK0yj1xVfqXqJZWCi/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1yzlEAQLghx1DaBhsTqHE6hObl13qtBkt/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1sJ7s98EkMxLOIGdPgkLJz7-kxunXYpFL/view?usp=drive_link",
    4: "https://drive.google.com/file/d/1nankaln6666hsOt-GM3zz24_w1v-f0nc/view?usp=drive_link",
}

generate_episode_table(episodes, title="Mahe Darakhshan")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">Mahe Darakhshan — All Episodes (1–4)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title">Mahe Darakhshan — Episodes</div>
#       <div class="ep-sub">4 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...

# %% [markdown]
# grok

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {
    1: "https://drive.google.com/file/d/1iJmjd5j_SiFJutIntZI11_ozFT-HqOv0/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1aHMB1lmChFL6KP8E_AAS6Jjxx8HZb-Yc/view?usp=drive_link",



}

generate_episode_table(episodes, title="Razin")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">Razin — All Episodes (1–2)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title">Razin — Episodes</div>
#       <div class="ep-sub">2 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...

# %% [markdown]
# for ankaboot

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1Z5vN_OAtFyzYBK2pRq6wA2EQoCg0b9i9/view?usp=drive_link",

     7: "https://drive.google.com/file/d/1ZGlNB5ffZnM0OdbFyT2s18CPaEFdSBOq/view?usp=drive_link",
     8: "https://drive.google.com/file/d/1fLO2SqlEKQiY0KO_u-4e6qJR0Ki7E2wO/view?usp=drive_link",
     9: "https://drive.google.com/file/d/1Hei4b8ebxshKYA1Dy7dYflxvT03vQTnR/view?usp=drive_link",
     10: "https://drive.google.com/file/d/1KOZ2EOua347W51bPisoq9QfL73LuBJ5-/view?usp=drive_link",
     11: "https://drive.google.com/file/d/1isUscDzqP6hdKV45ks1QdrWZ4j34NsQ9/view?usp=drive_link",
     12: "https://drive.google.com/file/d/1MAYyZfGOZEPA1p_hpDR_cydMcmWFo5V5/view?usp=drive_link",
     13: "https://drive.google.com/file/d/10_2LtmSbn41oAKbiA3TbNtnt7KourE8C/view?usp=drive_link",
     14: "https://drive.google.com/file/d/10oSeK_no6dgHnux_Y2G3rtVJNiHj7RpQ/view?usp=drive_link",
     15: "https://drive.google.com/file/d/1qgdK6wXTn5ddSOWyKlJFLqML4l2OkWOO/view?usp=drive_link",
     16: "https://drive.google.com/file/d/1iLt6JmIPVXQLqF3Hm4w-PCx5MKJw_ZFG/view?usp=drive_link",
     17: "https://drive.google.com/file/d/1yWah-RC6HUvMNQ-P8pVMky42kiA7i96B/view?usp=drive_link",
     18: "https://drive.google.com/file/d/1G4a1YB18g5ti39yDYeIFKZoOlcktEAOz/view?usp=drive_link",
     19: "https://drive.google.com/file/d/1ljDhaaheK4lkNZ4Trvm6S5Ftg1F4XLi6/view?usp=drive_link",
     20: "https://drive.google.com/file/d/14JtsVNtR93aKaS5g2xuqHoBxmM1Jfvod/view?usp=drive_link",
     21: "https://drive.google.com/file/d/1zcH3nLBOJC7Y6yclcRNEojGRFjr8Akyb/view?usp=drive_link",

    22:"https://drive.google.com/file/d/1kam5LolZGi05LM-XmmTEVYTK-6tQyofS/view?usp=drive_link"



}

generate_episode_table(episodes, title="Ankaboot")

# %% [markdown]
# for bisat novel

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1BngIT3l9osScpWxpYsTHRSYa0L8k2l8n/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1FWvE4O2IuTXTNgkOqU-HBCkWr_hhB1g6/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1AJKTj_3CJKmCYfP1Z8FcpRHUpFJ4IAxq/view?usp=drive_link",
    4: "https://drive.google.com/file/d/1H_jmI7CYA0f6BUgjOZ7-dtkzeAteTlka/view?usp=drive_link",
    5: "https://drive.google.com/file/d/1IX8k4mjHgsKpBlpux63Y_L36IuTp0IEt/view?usp=drive_link",
    6: "https://drive.google.com/file/d/17FtdS3Bv8447NPHjnWPh8JkYsY-1klxx/view?usp=drive_link",

    91: "https://drive.google.com/file/d/1egFjakUxGiWovdNURhF_qXMg32Ue_rcs/view?usp=drive_link",
    92: "https://drive.google.com/file/d/1IW4Rh1LebLepmX5nkC5L09mwFAA4RX8X/view?usp=drive_link",
    93: "https://drive.google.com/file/d/1kS96DlRYCyhq8dndeZQaxKDJmDMJx-fK/view?usp=drive_link",
    94: "https://drive.google.com/file/d/1pSpENdNnCyvCdvZ5VNbvs49vzAAXo3qF/view?usp=drive_link",
    95: "https://drive.google.com/file/d/1G1D6_N5yNkrdYoEQSzc_9IH5UMTedyfW/view?usp=drive_link",
    96: "https://drive.google.com/file/d/1wd5pyHWMeLPWpms5JmW81PTgjg2GkDVd/view?usp=drive_link",
    97: "https://drive.google.com/file/d/1FPNc6C0SUhsXiAJjYMM_vKQ4QhnruVU6/view?usp=drive_link",
    98: "https://drive.google.com/file/d/1Z9a4_1bJ-ADrnPdGX_o5AlwzY7Sokn72/view?usp=drive_link",
    99: "https://drive.google.com/file/d/11Jkk_FTDVten4PAJzORtE0w4IICeSuhH/view?usp=drive_link",
    100: "https://drive.google.com/file/d/1T4GYwTV13auNQvDf3ZYzby3cC1s0eUIX/view?usp=drive_link",
    101: "https://drive.google.com/file/d/1E2hlbAErIPqDQdZ8PTGDPjuSntb2sPrc/view?usp=drive_link",
    102: "https://drive.google.com/file/d/1wmTItmtmZjP4ZOuFmjuWzwe-mD0Bhw9T/view?usp=drive_link",
    103: "https://drive.google.com/file/d/1vO7Tdt0FI2n8mrzzuGZyLPfxQRa9z-Qo/view?usp=drive_link",
    104: "https://drive.google.com/file/d/1Kr7kqioV0vNJB209JSE5QW-8EW4bshwI/view?usp=drive_link",
    105: "https://drive.google.com/file/d/1f38nr9qI7j-mVq5vgSCdxtIOPu8-FjNS/view?usp=drive_link",
    106: "https://drive.google.com/file/d/1c2_5vi52sU1lvshG1-ZTpPWg1cNJz2pB/view?usp=drive_link",




}

generate_episode_table(episodes, title="Lahu se Laal")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">Lahu se Laal — All Episodes (1–22)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title">Lahu se Laal — Episodes</div>
#       <div class="ep-sub">22 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...

# %% [markdown]
# velutha novel

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1RYg6P-3-HbfEJepRNXIr28fSM4wOA0jD/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1-LrnG-x8vOXjnmYur2tlP4ENIs3yFv5L/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1FcDESazkeorfeR-sJdyzYgf0aJDg-cIo/view?usp=drive_link",
    4: "https://drive.google.com/file/d/1dVynyiPS5ttmu6NacyQHtTgYrwwxg_-P/view?usp=drive_link",
    5: "https://drive.google.com/file/d/1TfsW6XIRjbvheJ0t5o5uSXgS7HU7uG6g/view?usp=drive_link",
    6: "https://drive.google.com/file/d/1ghT25R-VHz4oBMe3jtRJotmL_tIPEnw-/view?usp=drive_link",
    7: "https://drive.google.com/file/d/1av6NatIvXxC75A3WpR9pkOH0Uf_n2cXi/view?usp=drive_link"




}

generate_episode_table(episodes, title="Velutha")

# %% [markdown]
# bharam baqa batil

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1aMwX8NR3YO5PMzMwb5QYzyGntH4cA_Jz/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1bTe1YYUK3aN9Kai8poerhMdvn-BaLl5a/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1evafAQqkZX3evyq80UV4CaR-u9T5d1xG/view?usp=drive_link",
    4: "https://drive.google.com/file/d/19A9mmGBo2T17O3hFclWhv6mTXn5BClLM/view?usp=drive_link",
    5: "https://drive.google.com/file/d/1lt-zQml_IlDMjq_z5nPn5vgANuwMVurt/view?usp=drive_link"





}

generate_episode_table(episodes, title=" Bharam Baqa batil")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;"> Bharam Baqa batil — All Episodes (1–5)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title"> Bharam Baqa batil — Episodes</div>
#       <div class="ep-sub">5 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1zIUK9q9PFv2FYRwaZ2FKb6y8hRFXTnYQ/view?usp=drive_link"




}

generate_episode_table(episodes, title="Kudsaar un Ishqi")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">Kudsaar un Ishqi — All Episodes (1–1)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title">Kudsaar un Ishqi — Episodes</div>
#       <div class="ep-sub">1 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...

# %%
from IPython.display import HTML, display
from html import escape

# === Function to extract Google Drive File ID ===
def extract_file_id(drive_url):
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError(f"Invalid Google Drive link: {drive_url}")
    return file_id


# === Function to generate episode table HTML ===
def generate_episode_table(episodes_dict, title="Ankaboot"):
    # Validate episode numbers
    if not episodes_dict:
        raise ValueError("Episodes dictionary cannot be empty")
    for ep_num in episodes_dict:
        if not isinstance(ep_num, int) or ep_num <= 0:
            raise ValueError(f"Invalid episode number: {ep_num}. Must be a positive integer.")

    # Check for duplicate URLs
    urls = list(episodes_dict.values())
    if len(urls) != len(set(urls)):
        print("Warning: Duplicate Google Drive URLs detected. Ensure each episode has a unique link.")

    # Sanitize title
    title = escape(title)

    # Sort episodes
    sorted_episodes = dict(sorted(episodes_dict.items()))

    html_start = f'''<div class="ep-container">
   <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">{title} — All Episodes (1–{len(episodes_dict)})</h2>
  <div class="ep-header">
  <div>
      <div class="ep-title">{title} — Episodes</div>
      <div class="ep-sub">{len(episodes_dict)} episodes — arranged for easy reading. Click an episode to open or download.</div>
    </div>
    <div class="ep-actions">
      <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
    </div>
  </div>

  <table class="ep-table">
    <thead>
      <tr>
        <th>Read Episodes Online</th>
        <th>Download PDF</th>
      </tr>
    </thead>
    <tbody>
'''

    rows = ""
    for ep_num, drive_link in sorted_episodes.items():
        try:
            file_id = extract_file_id(drive_link)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        except ValueError:
            file_id = "INVALID"
            download_link = "#"

        row = f'''      <tr>
        <td><a href="{drive_link}" target="_blank" rel="noopener noreferrer" title="Read {title} Episode {ep_num} Online">Episode {ep_num} — Read Online</a></td>
        <td class="ep-download"><a href="{download_link}" target="_blank" rel="noopener noreferrer" title="Download {title} Episode {ep_num}">Download</a></td>
      </tr>\n'''
        rows += row

    html_end = '''    </tbody>
  </table>
</div>'''

    final_html = html_start + rows + html_end

    # Display nicely in Colab with a copy button
    display(HTML(f"""
    <h3>✅ Generated HTML Table Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{final_html}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Table Code</button>
    <p style="color:gray;">You can paste this directly into your Blogger post HTML view.</p>
    """))


# === 🔹 Example usage ===
episodes = {

    1: "https://drive.google.com/file/d/1UsmwLewrnfpQxpu3npemC7aQ7B3rktB7/view?usp=drive_link",
    2: "https://drive.google.com/file/d/1s5763if2KJUPy7cFSYk87tpCFKI9Ae0J/view?usp=drive_link",
    3: "https://drive.google.com/file/d/1cKYwiaSahHkc_-TpuoStf3iE6TAMeFR_/view?usp=drive_link",
    4: "https://drive.google.com/file/d/1J-dGoKKaUDi2CUIn6wFuJJUW8FVtWzWn/view?usp=drive_link",
    5: "https://drive.google.com/file/d/1JPo5MFJQXytrrZQEMk6h2l0X1N8E8kIV/view?usp=drive_link",
    6: "https://drive.google.com/file/d/1raW14Rj2Yie3I8vxwuG8BxlIdcWiU3gm/view?usp=drive_link",
    7: "https://drive.google.com/file/d/1I3-s2yfqc_p4ijkrwnMJS_qfHQaJu4Qi/view?usp=drive_link",
    8: "https://drive.google.com/file/d/1HQiv2lvYskVkllV4sYyspOlOWVCxSmow/view?usp=drive_link",
    9: "https://drive.google.com/file/d/1AxjeOkgbg4gamKzO26__wpNGVM1kbUiO/view?usp=drive_link",
    10: "https://drive.google.com/file/d/146TOrnamIPlgLiF3gWa-dh5FgHHrzeeF/view?usp=drive_link",
    11: "https://drive.google.com/file/d/1RXqr_O-xwaayoQlaw5jKuGpkIKJzO3U0/view?usp=drive_link",




}

generate_episode_table(episodes, title="Zanzaniya")
# Out:
#     <h3>✅ Generated HTML Table Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;"><div class="ep-container">
#    <h2 style="text-align:center; font-size:24px; margin-bottom:16px;">Zanzaniya — All Episodes (1–11)</h2>
#   <div class="ep-header">
#   <div>
#       <div class="ep-title">Zanzaniya — Episodes</div>
#       <div class="ep-sub">11 episodes — arranged for easy reading. Click an episode to open or download.</div>
#     </div>
#     <div class="ep-actions">
#       <small style="color:#475569;">View: <span style="font-weight:700">Table</span></small>
#     </div>
#   </div>
#
#   <table class="ep-table">
#     <thead>
#       <tr>
#         <th>Read Episodes Online</th>
#         <th>Download PDF</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
# ...
