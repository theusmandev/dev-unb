# %%
import re
from IPython.display import HTML, display

def capitalize_each_word(text):
    """ہر لفظ کا پہلا حرف بڑا کرتا ہے (Title Case)"""
    if not text:
        return text
    return ' '.join(word.capitalize() for word in text.split())

def generate_simple_download_section(drive_url, novel_title):
    # 🔹 Extract Google Drive File ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    # 🔹 URLs
    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # 🔹 Extract Novel Name & Author + ہر لفظ کا پہلا حرف بڑا
    match = re.search(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = capitalize_each_word(match.group(1).strip())
        author_name = capitalize_each_word(match.group(2).strip())
    else:
        novel_name = capitalize_each_word(novel_title.strip())
        author_name = "Fatima Malik"

    # 🔹 Post Tags (یہاں بھی title case استعمال کر سکتے ہیں)
    tags = f"{novel_name} PDF, {author_name} Novels, Download Urdu Novel, Read Online Urdu Novel, {novel_name} Review"

    # 🔹 Urdu Note Section (کوئی تبدیلی نہیں)
    urdu_note = """
<p> </p>
<div>
<blockquote>
<div dir="rtl" style="text-align: center;">
<b><span style="color: red; font-size: large;">نوٹ :</span></b>
</div>
<div dir="rtl" style="text-align: center;"><span style="font-size: medium;"><br /></span></div>
<div dir="rtl" style="text-align: center;"><span style="font-size: medium;">
یہ ناول ریویو محض ایک قاری کے ذاتی احساسات اور مشاہدات کی عکاسی کرتا ہے۔
ہم ہمیشہ اپنے قارئین کو یہی مشورہ دیتے ہیں کہ کسی بھی کتاب کے بارے میں
حتمی رائے قائم کرنے سے پہلے اسے خود ضرور پڑھیں، کیونکہ ہر کہانی ہر دل میں
الگ انداز سے اترتی ہے اور ہر قاری کا تجربہ منفرد ہوتا ہے۔<br><br> اگر آپ اس ریویو
سے متفق نہیں ہیں تو آپ کی رائے بھی ہمارے لیے اتنی ہی قابلِ احترام ہے۔
آپ اپنے تاثرات، ریویو یا مختلف نقطۂ نظر کمنٹ سیکشن میں ضرور شیئر کریں،
کیونکہ کتابوں پر صحت مند گفتگو ہی ادب کو زندہ اور متحرک رکھتی ہے۔
</div>
</blockquote>
<div dir="rtl" style="text-align: center;"></div>
<div>..</div>
</div>
"""

    # 🔹 Final HTML Output
    html_code = f"""

 {novel_name} Novel by {author_name} – Read Review and Download PDF

    <br>
    <div style="text-align: left;">
  <span style="font-size: medium;">
    <b><i>Review By:</i></b>
    <span style="color: #ff0b67;">@anushaarifbaig._/</span>
  </span>
</div>
<br>
<h2>
Download {novel_name} Novel by {author_name}
</h2>

<div style="display:flex;justify-content:center;">
    <iframe
        loading="lazy"
        src="{preview_url}"
        style="width:100%;max-width:640px;height:480px;">
    </iframe>
</div>
<br>
<div style="display:flex;justify-content:center;margin:20px 0;">
    <a href="{download_url}"
       target="_blank"
       rel="noopener noreferrer"
       class="custom-download-btn">
       Download PDF
    </a>
</div>
<br>
<div class="unb-rn-lib-wrap" data-rss="https://www.urdunovelbanks.com/feeds/posts/default/-/Novel%20Reviews?alt=json-in-script&amp;callback=myLibraryLoad&amp;max-results=150">

 <div class="unb-rn-lib-box">
  <div class="unb-rn-lib-head"><h3>Read More Novel Reviews</h3></div>

  <div class="unb-rn-lib-grid" id="unbLibGrid">
   <div class="unb-rn-lib-net" id="unbNetStatus">
    Slow Internet?
    <span class="unb-rn-lib-retry" onclick="retryFetch()">Refresh</span>
   </div>

   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
  </div>

  <div class="unb-rn-lib-btnwrap" id="unbLibBtn">
   <a class="unb-rn-lib-btn" href="https://www.urdunovelbanks.com/2026/01/romantic-urdu-novels-explore-complete.html">
    Load Complete Library
   </a>
  </div>
 </div>
</div>
<br>
{urdu_note}
<h3 style="text-align:center;">Post Tags</h3>
<p><i>{tags}</i></p>
"""

    # 🔹 Display for Blogger
    display(HTML(f"""
    <h3>📄 Blogger Embed Code</h3>
    <textarea id="code" style="width:100%;height:320px;">{html_code}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('code').value)">
    📋 Copy Code
    </button>
    """))


# --------------------------
# ✅ Example Usage
drive_link = "https://drive.google.com/file/d/1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33/view?usp=drive_link"
novel_title = "Daasi Dholan yar De by Faiza Iftikhar"

generate_simple_download_section(drive_link, novel_title)
# Out:
#     <h3>📄 Blogger Embed Code</h3>
#     <textarea id="code" style="width:100%;height:320px;">
#
#  Daasi Dholan Yar De Novel by Faiza Iftikhar – Read Review and Download PDF
#
#     <br>
#     <div style="text-align: left;">
#   <span style="font-size: medium;">
#     <b><i>Review By:</i></b>
#     <span style="color: #ff0b67;">@anushaarifbaig._/</span>
#   </span>
# </div>
# <br>
# <h2>
# Download Daasi Dholan Yar De Novel by Faiza Iftikhar
# </h2>
#
# <div style="display:flex;justify-content:center;">
#     <iframe
#         loading="lazy"
#         src="https://drive.google.com/file/d/1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33/preview"
#         style="width:100%;max-width:640px;height:480px;">
#     </iframe>
# </div>
# <br>
# <div style="display:flex;justify-content:center;margin:20px 0;">
#     <a href="https://drive.google.com/uc?export=download&id=1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33"
#        target="_blank"
#        rel="noopener noreferrer"
#        class="custom-download-btn">
# ...

# %%
import re
from IPython.display import HTML, display

def generate_simple_download_section(drive_url, novel_title):
    # 🔹 Extract Google Drive File ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    # 🔹 URLs
    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # 🔹 Extract Novel Name & Author
    match = re.search(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Fatima Malik"

    # 🔹 Post Tags
    tags = f"{novel_name} PDF, {author_name} Novels, Download Urdu Novel, Read Online Urdu Novel,{novel_name} Review"

    # 🔹 Urdu Note Section
    urdu_note = """
<p>&nbsp;</p>
<div>
<blockquote>
<div dir="rtl" style="text-align: center;">
<b><span style="color: red; font-size: medium;">نوٹ :</span></b>
</div>
<div dir="rtl" style="text-align: center;"><span style="font-size: medium;"><br /></span></div>
<div dir="rtl" style="text-align: center;"><span style="font-size: medium;">
یہ ناول ریویو محض ایک قاری کے ذاتی احساسات اور مشاہدات کی عکاسی کرتا ہے۔
ہم ہمیشہ اپنے قارئین کو یہی مشورہ دیتے ہیں کہ کسی بھی کتاب کے بارے میں
حتمی رائے قائم کرنے سے پہلے اسے خود ضرور پڑھیں، کیونکہ ہر کہانی ہر دل میں
الگ انداز سے اترتی ہے اور ہر قاری کا تجربہ منفرد ہوتا ہے۔ <br><br>اگر آپ اس ریویو
سے متفق نہیں ہیں تو آپ کی رائے بھی ہمارے لیے اتنی ہی قابلِ احترام ہے۔
آپ اپنے تاثرات، ریویو یا مختلف نقطۂ نظر کمنٹ سیکشن میں ضرور شیئر کریں،
کیونکہ کتابوں پر صحت مند گفتگو ہی ادب کو زندہ اور متحرک رکھتی ہے۔
</div>
</blockquote>
<div dir="rtl" style="text-align: center;"></div>
<div>..</div>
</div>
"""

    # 🔹 Final HTML Output
    html_code = f"""
<h2>
Download {novel_name} Novel by {author_name}
</h2>

<div style="display:flex;justify-content:center;">
    <iframe
        loading="lazy"
        src="{preview_url}"
        style="width:100%;max-width:640px;height:480px;">
    </iframe>
</div>
<br>
<div style="display:flex;justify-content:center;margin:20px 0;">
    <a href="{download_url}"
       target="_blank"
       rel="noopener noreferrer"
       class="custom-download-btn">
       Download PDF
    </a>
</div>
{urdu_note}
<div class="unb-rn-lib-wrap" data-rss="https://www.urdunovelbanks.com/feeds/posts/default/-/Novel%20Reviews?alt=json-in-script&amp;callback=myLibraryLoad&amp;max-results=50">

 <div class="unb-rn-lib-box">
  <div class="unb-rn-lib-head">Read More Novel Reviews</div>

  <div class="unb-rn-lib-grid" id="unbLibGrid">
   <div class="unb-rn-lib-net" id="unbNetStatus">
    Slow Internet?
    <span class="unb-rn-lib-retry" onclick="retryFetch()">Refresh</span>
   </div>

   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
   <div class="unb-rn-lib-card"><div class="unb-rn-lib-skel"></div></div>
  </div>

  <div class="unb-rn-lib-btnwrap" id="unbLibBtn">
   <a class="unb-rn-lib-btn" href="https://www.urdunovelbanks.com/2026/01/romantic-urdu-novels-explore-complete.html">
    Load Complete Library
   </a>
  </div>
 </div>
</div>
<br>
<h3 style="text-align:center;">Post Tags</h3>

<p>
<i>{tags}</i>
</p>
"""

    # 🔹 Display for Blogger
    display(HTML(f"""
    <h3>📄 Blogger Embed Code</h3>
    <textarea id="code" style="width:100%;height:320px;">{html_code}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('code').value)">
    📋 Copy Code
    </button>
    """))


# --------------------------
# ✅ Example Usage
drive_link = "https://drive.google.com/file/d/1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33/view?usp=drive_link"
novel_title = "Daasi Dholan yar De by Faiza Iftikhar"

generate_simple_download_section(drive_link, novel_title)
# Out:
#     <h3>📄 Blogger Embed Code</h3>
#     <textarea id="code" style="width:100%;height:320px;">
# <h2>
# Download Daasi Dholan yar De Novel by Faiza Iftikhar
# </h2>
#
# <div style="display:flex;justify-content:center;">
#     <iframe
#         loading="lazy"
#         src="https://drive.google.com/file/d/1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33/preview"
#         style="width:100%;max-width:640px;height:480px;">
#     </iframe>
# </div>
# <br>
# <div style="display:flex;justify-content:center;margin:20px 0;">
#     <a href="https://drive.google.com/uc?export=download&id=1P_0vRWFZQPTbhF07RtA5Uq5sVJUQ9t33"
#        target="_blank"
#        rel="noopener noreferrer"
#        class="custom-download-btn">
#        Download PDF
#     </a>
# </div>
#
# <p>&nbsp;</p>
# <div>
# <blockquote>
# <div dir="rtl" style="text-align: center;">
# <b><span style="color: red; font-size: medium;">نوٹ :</span></b>
# </div>
# ...

# %%
import re
from IPython.display import HTML, display

def generate_simple_download_section(drive_url, novel_title):
    # 🔹 Extract Google Drive File ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    # 🔹 URLs
    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # 🔹 Extract Novel Name & Author
    match = re.search(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Fatima Malik"

    # 🔹 Post Tags
    tags = f"{novel_name} PDF, {author_name} Novels, Download Urdu Novel, Read Online Urdu Novel"

    # 🔹 Final HTML Output
    html_code = f"""
<h2 style="text-align:center;">
Download {novel_name} Novel by {author_name}
</h2>

<div style="display:flex;justify-content:center;">
    <iframe
        loading="lazy"
        src="{preview_url}"
        style="width:100%;max-width:640px;height:480px;border:none;">
    </iframe>
</div>

<div style="display:flex;justify-content:center;margin:20px 0;">
    <a href="{download_url}"
       target="_blank"
       rel="noopener noreferrer"
       class="custom-download-btn">
       Download PDF
    </a>
</div>

<h3 style="text-align:center;">Post Tags</h3>

<p style="text-align:center;">
<i>{tags}</i>
</p>
"""

    # 🔹 Display for Blogger
    display(HTML(f"""
    <h3>📄 Blogger Embed Code</h3>
    <textarea id="code" style="width:100%;height:260px;">{html_code}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('code').value)">
    📋 Copy Code
    </button>
    """))


# --------------------------
# ✅ Example Usage
drive_link = "https://drive.google.com/file/d/16aUgZhDzKtN1DCPLnhU4d2xm6sP9JotX/view"
novel_title = "Yeh Ishq Hai Novel By Fatima Malik"

generate_simple_download_section(drive_link, novel_title)
# Out:
#     <h3>📄 Blogger Embed Code</h3>
#     <textarea id="code" style="width:100%;height:260px;">
# <h2 style="text-align:center;">
# Download Yeh Ishq Hai Novel Novel by Fatima Malik
# </h2>
#
# <div style="display:flex;justify-content:center;">
#     <iframe
#         loading="lazy"
#         src="https://drive.google.com/file/d/16aUgZhDzKtN1DCPLnhU4d2xm6sP9JotX/preview"
#         style="width:100%;max-width:640px;height:480px;border:none;">
#     </iframe>
# </div>
#
# <div style="display:flex;justify-content:center;margin:20px 0;">
#     <a href="https://drive.google.com/uc?export=download&id=16aUgZhDzKtN1DCPLnhU4d2xm6sP9JotX"
#        target="_blank"
#        rel="noopener noreferrer"
#        class="custom-download-btn">
#        Download PDF
#     </a>
# </div>
#
# <h3 style="text-align:center;">Post Tags</h3>
#
# <p style="text-align:center;">
# <i>Yeh Ishq Hai Novel PDF, Fatima Malik Novels, Download Urdu Novel, Read Online Urdu Novel</i>
# </p>
# </textarea>
# ...
