# %%
import re
from IPython.display import HTML, display

def generate_novel_post_for_blogger_noor_rajpoot_clean(drive_url, novel_title):
    # ✅ Extract Google Drive file ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    # ✅ Create preview and download URLs
    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # ✅ Extract author name
    match = re.match(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Noor Rajpoot"

    # ✅ SEO labels
    labels = [
         "Download All Noor Rajpoot Novels",
        "Noor Rajpoot",
        "Noor Rajpoot Novels",
        "Noor Rajpoot Books",
        "Download All Noor Rajpoot Books"
    ]

    # ✅ Meta description
    description = f"{novel_title} is a soulful and mysterious Urdu story by Noor Rajpoot, exploring love, belief, and destiny."
    description = description[:150]

    # ✅ Clean HTML using Blogger theme CSS
    html_content = f"""

    <h1>{novel_title} | Download PDF</h1>


<div class="novel-post">
    <p><b>{novel_title}</b> is a beautifully crafted Urdu novel that blends <b>romance</b>, <b>spiritual awakening</b>, and <b>psychological intrigue</b> into a single, captivating narrative.
    Penned by <b>{author_name}</b>, one of the distinctive voices in modern Urdu fiction, this novel takes readers through a journey of heart, belief, and reflection.</p>

    <p><b>{author_name}</b> stands out as a writer who connects the emotional and spiritual worlds through her characters.
    Her writings portray life’s dualities — <b>light and shadow, faith and fear, love and loss</b> — in a way that resonates deeply with Urdu readers of all ages.</p>

    <p>Her passion for storytelling is visible in every line she writes. With her creative vision, she has built a world of <b>mystery, emotion, and faith</b> that feels both timeless and relatable.
    Her major works like <i>Sulphite</i>, <i>Maseel</i>, <i>Ankaboot</i>, <i>The Volverine</i>, <i>Hinavae</i>, and <i>The Medium</i> are living proof of her storytelling mastery.</p>

    <p><b>{novel_name}</b> explores the inner world of human emotion and divine connection, showing how fate and free will collide in life’s mysterious path.
    It’s not just a story — it’s an experience that stays in the reader’s heart long after the last page.</p>

    <p>Now available on <b>Urdu Fiction Bank</b>, you can <b>read {novel_title} online</b> or <b>download the full PDF</b> version completely free.
    Step into Noor Rajpoot’s world of emotion, destiny, and faith — where every line whispers a deeper meaning.</p>

    <div class="novel-details">
        <h2>📘 Book Details</h2>
        <ul>
            <li><b>Book Name:</b> {novel_name}</li>
            <li><b>Author:</b> {author_name}</li>
            <li><b>Status:</b> Completed</li>
            <li><b>Language:</b> Urdu</li>
            <li><b>Format:</b> PDF + Read Online</li>
        </ul>
    </div>

    <div class="novel-read">
        <h2>📖 Read Online {novel_title}</h2>
        <iframe loading="lazy" src="{preview_url}"></iframe>
    </div>

    <div class="novel-download">
         <a href="{download_url}" target="_blank" rel="noopener noreferrer">Download PDF</a>
    </div>
<br>
    <div class="novel-tags">
        <h3>🏷️ Tags:</h3>
        <i>{novel_title} Free PDF, {author_name} Urdu Books, Read Online {novel_name}, Best Novel By Noor Rajpoot</i>
    </div>
</div>
"""

    # ✅ Display output for Blogger copy
    display(HTML(f"""
    <h3>📄 Blogger Embed Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{html_content}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Embed Code</button>

    <h3>🏷️ Blogger Labels</h3>
    <textarea id="labels_code" style="width:100%;height:100px;">{', '.join(labels)}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('labels_code').value)">📋 Copy Labels</button>

    <h3>📝 SEO Description</h3>
    <textarea id="description_code" style="width:100%;height:100px;">{description}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('description_code').value)">📋 Copy Description</button>
    """))


# ✅ Example usage
drive_link = "https://drive.google.com/file/d/1iE0PjGz5JriOAgx2r1pLJPKlkVM7c4ng/view?usp=drive_link"
novel_title = "Ankaboot novel by Noor Rajpoot"
generate_novel_post_for_blogger_noor_rajpoot_clean(drive_link, novel_title)
# Out:
#     <h3>📄 Blogger Embed Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;">
#
#     <h1>Ankaboot novel by Noor Rajpoot | Download PDF</h1>
#
#
# <div class="novel-post">
#     <p><b>Ankaboot novel by Noor Rajpoot</b> is a beautifully crafted Urdu novel that blends <b>romance</b>, <b>spiritual awakening</b>, and <b>psychological intrigue</b> into a single, captivating narrative.
#     Penned by <b>Noor Rajpoot</b>, one of the distinctive voices in modern Urdu fiction, this novel takes readers through a journey of heart, belief, and reflection.</p>
#
#     <p><b>Noor Rajpoot</b> stands out as a writer who connects the emotional and spiritual worlds through her characters.
#     Her writings portray life’s dualities — <b>light and shadow, faith and fear, love and loss</b> — in a way that resonates deeply with Urdu readers of all ages.</p>
#
# ...

# %%
import re
from IPython.display import HTML, display

def generate_novel_post_for_blogger_umera_ahmed(drive_url, novel_title):
    # ✅ Extract Google Drive file ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    # ✅ Create preview and download URLs
    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # ✅ Extract author name
    match = re.match(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Umera Ahmed"

    # ✅ SEO labels
    labels = [
        "Umera Ahmed Novels",
        "Download All Umera Ahmed Books",
        "Aab e Hayat by Umera Ahmed",
        "Umera Ahmed",
        "Best Urdu Novels",
        "Urdu Fiction Bank"
    ]

    # ✅ SEO meta description
    description = f"{novel_title} is one of the most inspiring Urdu novels by Umera Ahmed, exploring love, faith, and spiritual growth."
    description = description[:150]

    # ✅ Blogger HTML post content
    html_content = f"""
    <h1>{novel_title} | Download PDF</h1>

<div class="novel-post">
    <p><b>{novel_title}</b> is one of the finest works by <b>{author_name}</b> — a legendary Urdu novelist whose writings touch the heart and soul.
    Her storytelling blends <b>faith, love, spirituality, and human emotions</b> in a way that inspires readers and transforms perspectives.</p>

    <p>{author_name}'s novels are deeply rooted in real-life experiences, exploring how people struggle between <b>faith and materialism</b>,
    and how belief in Allah can change one’s destiny. Her stories carry emotional depth and moral lessons that make them timeless.</p>

    <p>Some of her most acclaimed works include <i>Pir-e-Kamil</i>, <i>La Hasil</i>, <i>Shehr-e-Zaat</i>, <i>Zindagi Gulzar Hai</i>, and <i>Aab-e-Hayat</i>.
    Each of these novels inspires readers to reconnect with spirituality, purpose, and inner peace.</p>

    <p><b>{novel_name}</b> continues the legacy of meaningful Urdu fiction — filled with life-changing lessons, soulful characters, and a powerful connection to divine love.
    It’s a must-read for every Urdu literature lover who enjoys stories that go beyond emotions and touch the soul.</p>

    <p>Now available on <b>Urdu Novel Bank</b>, you can <b>read {novel_title} online</b> or <b>download the full PDF</b> version absolutely free.
    Step into Umera Ahmed’s world of <b>faith, love, and transformation</b> — where every word leaves a lasting impact.</p>

    <div class="novel-details">
        <h2>📘 Book Details</h2>
        <ul>
            <li><b>Book Name:</b> {novel_name}</li>
            <li><b>Author:</b> {author_name}</li>
            <li><b>Status:</b> Completed</li>
            <li><b>Language:</b> Urdu</li>
            <li><b>Format:</b> PDF + Read Online</li>
        </ul>
    </div>

    <div class="novel-read">
        <h2>📖 Read Online {novel_title}</h2>
        <iframe loading="lazy" src="{preview_url}"></iframe>
    </div>

    <div class="novel-download">
        <a href="{download_url}" target="_blank" rel="noopener noreferrer">📥 Download PDF</a>
    </div>
<br>
    <div class="novel-tags">
        <h3>🏷️ Tags:</h3>
        <i>{novel_title} PDF Download, {author_name} Urdu Books, Read Online {novel_name}, Best Urdu Novels by Umera Ahmed</i>
    </div>
</div>
"""

    # ✅ Display Blogger Output
    display(HTML(f"""
    <h3>📄 Blogger Embed Code</h3>
    <textarea id="final_code" style="width:100%;height:300px;">{html_content}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)">📋 Copy Embed Code</button>

    <h3>🏷️ Blogger Labels</h3>
    <textarea id="labels_code" style="width:100%;height:100px;">{', '.join(labels)}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('labels_code').value)">📋 Copy Labels</button>

    <h3>📝 SEO Description</h3>
    <textarea id="description_code" style="width:100%;height:100px;">{description}</textarea>
    <button onclick="navigator.clipboard.writeText(document.getElementById('description_code').value)">📋 Copy Description</button>
    """))


# ✅ Example usage
drive_link = "https://drive.google.com/file/d/1e9Zez1s4sDl1O8Ww2bsfo-fwAd_vQtlH/view?usp=drive_link"
novel_title = "Wapsi novel by Umera Ahmed"
generate_novel_post_for_blogger_umera_ahmed(drive_link, novel_title)
# Out:
#     <h3>📄 Blogger Embed Code</h3>
#     <textarea id="final_code" style="width:100%;height:300px;">
#     <h1>Wapsi novel by Umera Ahmed | Download PDF</h1>
#
# <div class="novel-post">
#     <p><b>Wapsi novel by Umera Ahmed</b> is one of the finest works by <b>Umera Ahmed</b> — a legendary Urdu novelist whose writings touch the heart and soul.
#     Her storytelling blends <b>faith, love, spirituality, and human emotions</b> in a way that inspires readers and transforms perspectives.</p>
#
#     <p>Umera Ahmed's novels are deeply rooted in real-life experiences, exploring how people struggle between <b>faith and materialism</b>,
#     and how belief in Allah can change one’s destiny. Her stories carry emotional depth and moral lessons that make them timeless.</p>
#
#     <p>Some of her most acclaimed works include <i>Pir-e-Kamil</i>, <i>La Hasil</i>, <i>Shehr-e-Zaat</i>, <i>Zindagi Gulzar Hai</i>, and <i>Aab-e-Hayat</i>.
# ...
