# %%
import re
from IPython.display import HTML, display

def generate_palk_jhapaktay_v3(drive_url, novel_title):
    # ✅ Extract Google Drive file ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # ✅ Extract author name
    match = re.match(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Famous Urdu Writer"

    # ✅ SEO Metadata
    labels = ["پلک جھپکتے قصے", f"{author_name} Novels", "Short Urdu Stories", f"{author_name}"]
    description = f"Read online or download {novel_name} by {author_name}. Part of our 'Palk Jhapaktay Kissay' segment. Best short Urdu romantic novels at Urdu Novel Bank."

    # ✅ Exact HTML Format Provided by User
    html_content = f"""<h1 style="text-align: center;">
  {novel_name} By {author_name} – Short Novel
</h1>

<h2 style="text-align: center;">✨ پلک جھپکتے قصے ✨</h2>

<div dir="rtl" style="text-align: right;">
  <p>
    <b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔
    یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
  </p>
<br />
  <p>
    اس سیگمنٹ میں شامل کہانیاں آپ <b>35 سے 40 منٹ</b> میں آسانی سے مکمل کر سکتے ہیں،
    مگر ان کا اثر دیر تک دل میں رہتا ہے۔
  </p>
<br />
  <p>
    آج کی ہماری کہانی <b>"{novel_name}"</b>
    جسے <b>{author_name}</b> نے تحریر کیا ہے،
    اُن لوگوں کے لیے ہے جو مصروف زندگی کے باوجود کہانیوں سے جڑے رہنا چاہتے ہیں۔
  </p>
<br />
  <p style="text-align: center;">
    <b>✨ آپ کے 40 منٹ، ایک خوبصورت کہانی کے لیے ✨</b>
  </p>
</div>
<br />
<h2>Quick Book Overview</h2>
<ul>
  <li><b>Book Title:</b> {novel_name}</li>
  <li><b>Written By:</b> {author_name}</li>
  <li><b>Segment:</b> پلک جھپکتے قصے (Short Story)</li>
  <li><b>Availability:</b> PDF + Read Online</li>
</ul>
<br />
<h2 style="text-align: center;">Read Online {novel_name}</h2>

<div style="display:flex; justify-content:center; margin:25px 0; padding: 0 15px;">
  <iframe loading="lazy" src="{preview_url}" style="width:100%; max-width:650px; aspect-ratio:3/4; min-height:450px;">
  </iframe>
</div>
<br />
<div style="margin: 20px 0px; text-align: center;">
  <a class="custom-download-btn" href="{download_url}" rel="noopener noreferrer" target="_blank" title="Download {novel_name} PDF">
      Download PDF
  </a>
</div>
<br />
<div style="display: flex; justify-content: center;">
  <a href="https://www.urdunovelbanks.com/2025/12/segment-palak-japkhtay-qissay-novels.html" style="border-radius: 5px; border: 1px dashed rgb(233, 30, 99); font-size: 18px; padding: 6px 12px; text-decoration: none;"><span face="Arial, sans-serif" style="color: #e91e63; font-family: Gulzar;">
      پلک جھپکتے قصے کی باقی کہانیاں پڑھیں👈
  </span></a>
</div>

<br />
<h2 style="text-align: center;">Story Tags</h2>
<p style="text-align: center;">
  {novel_name} PDF,
  {author_name} Short Stories,
  پلک جھپکتے قصے,
  Urdu Novel Bank,
  {novel_name} Online Reading
</p>
"""

    # ✅ Colab UI Layout
    display(HTML(f"""
    <div style="border: 2px solid #ccc; padding: 20px; border-radius: 10px; background-color: #fcfcfc; font-family: sans-serif;">
        <h3 style="color: #d81b60;">📄 Blogger Embed Code (Palk Jhapaktay Kissay)</h3>
        <textarea id="final_code" style="width:100%;height:300px; border: 1px solid #ddd; padding: 10px;">{html_content}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)" style="margin: 10px 0; padding: 10px 20px; cursor: pointer; background: #d81b60; color: white; border: none; border-radius: 5px;">📋 Copy HTML Code</button>

        <h3 style="color: #1976d2;">🏷️ Labels</h3>
        <textarea id="labels_code" style="width:100%;height:50px; border: 1px solid #ddd; padding: 10px;">{', '.join(labels)}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('labels_code').value)" style="margin: 10px 0; padding: 10px 20px; cursor: pointer; background: #1976d2; color: white; border: none; border-radius: 5px;">📋 Copy Labels</button>

        <h3 style="color: #388e3c;">📝 SEO Description</h3>
        <textarea id="description_code" style="width:100%;height:50px; border: 1px solid #ddd; padding: 10px;">{description}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('description_code').value)" style="margin: 10px 0; padding: 10px 20px; cursor: pointer; background: #388e3c; color: white; border: none; border-radius: 5px;">📋 Copy Description</button>
    </div>
    """))

# ✅ Usage
drive_link = "https://drive.google.com/file/d/1dYNRQvGJPCCD1PoueTJZO48bmCEHnOB0/view?usp=drive_link"
novel_title = "Bano By Sumiara Hameed"

generate_palk_jhapaktay_v3(drive_link, novel_title)
# Out:
#     <div style="border: 2px solid #ccc; padding: 20px; border-radius: 10px; background-color: #fcfcfc; font-family: sans-serif;">
#         <h3 style="color: #d81b60;">📄 Blogger Embed Code (Palk Jhapaktay Kissay)</h3>
#         <textarea id="final_code" style="width:100%;height:300px; border: 1px solid #ddd; padding: 10px;"><h1 style="text-align: center;">
#   Bano By Sumiara Hameed – Short Novel
# </h1>
#
# <h2 style="text-align: center;">✨ پلک جھپکتے قصے ✨</h2>
#
# <div dir="rtl" style="text-align: right;">
#   <p>
#     <b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔
#     یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
#   </p>
# <br />
#   <p>
#     اس سیگمنٹ میں شامل کہانیاں آپ <b>35 سے 40 منٹ</b> میں آسانی سے مکمل کر سکتے ہیں،
#     مگر ان کا اثر دیر تک دل میں رہتا ہے۔
#   </p>
# <br />
#   <p>
#     آج کی ہماری کہانی <b>"Bano"</b>
# ...

# %%
import re
from IPython.display import HTML, display

def generate_palk_jhapaktay_post(drive_url, novel_title):
    # ✅ Extract Google Drive file ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # ✅ Extract author name
    match = re.match(r"(.+?)\s+by\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Famous Urdu Writer"

    # ✅ SEO Metadata
    labels = ["پلک جھپکتے قصے", f"{author_name} Novels", "Short Urdu Stories", f"{author_name}"]
    description = f"Read online or download {novel_name} by {author_name}. A special short story from our 'Palk Jhapaktay Kissay' segment. Best Urdu short stories at Urdu Novel Bank."

    # ✅ Human-Touch SEO Content (Customized for your segment)
    long_description = f"""
<div dir="rtl" style="text-align: right;">
<p><span style="font-family: Arial, sans-serif;">
<b>✨ پلک جھپکتے قصے ✨</b>
<br><br>
<b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔ یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
</span></p>

<p><span style="font-family: Arial, sans-serif;">
اس سیگمنٹ میں شامل کہانیاں آپ <b>35 سے 40 منٹ</b> میں آسانی سے مکمل کر سکتے ہیں، مگر ان کا اثر دیر تک دل میں رہتا ہے۔ ہر کہانی الگ موضوع پر ہے اور اپنے اندر ایک خاص احساس سموئے ہوئے ہے۔
</span></p>

<p><span style="font-family: Arial, sans-serif;">
آج کی ہماری کہانی <b>"{novel_name}"</b> جسے <b>{author_name}</b> نے تحریر کیا ہے، اُن لوگوں کے لیے ہے جو مصروف زندگی کے باوجود کہانیوں سے جڑے رہنا چاہتے ہیں۔
<br><b>✨ آپ کے 40 منٹ، ایک خوبصورت کہانی کے لیے ✨</b>
</span></p>
</div>
<br>
"""

    # ✅ Exact Original HTML Format (Keeping your exact styling)
    html_content = f"""<h1 style="text-align: center;">{novel_name} By {author_name} – پلک جھپکتے قصے</h1>
<div>
    {long_description}
    <h2><i><span style="font-family: Arial, sans-serif;">Quick Book Overview</span></i></h2>
    <ul>
        <li><i><b>Book Title:</b> {novel_name}</i></li>
        <li><i><b>Written By:</b> {author_name}</i></li>
        <li><i><b>Segment:</b> پلک جھپکتے قصے (Short Story)</i></li>
        <li><i><b>Reading Time:</b> 35-40 Minutes</i></li>
        <li><i><b>Availability:</b> PDF + Read Online</i></li>
    </ul><br>
    <h2><i><span style="font-family: Arial, sans-serif;">Read Online {novel_name}</span></i></h2>
</div>

<div>
    <div style="display:flex;justify-content:center;">
        <iframe loading="lazy" style="width:100%;max-width:640px;height:480px;" class="novel-iframe" src="{preview_url}"></iframe>
    </div>
    <div style="display:flex;justify-content:center;margin:20px 0;">
    </div>
    <div style="display:flex;justify-content:center;">
        <a href="{download_url}" class="custom-download-btn" target="_blank" rel="noopener noreferrer" title="Download {novel_name} By {author_name}">Download PDF</a>
    </div>
<br>
    <div style="display:flex;justify-content:center;margin-top:20px;">
        <h2 style="font-family:'Times New Roman',serif;font-style:normal;text-align:left;">
            <i><span style="font-family:Arial,sans-serif;font-weight:normal;">Novel Tags:</span></i>
        </h2>
    </div>
    <div style="display:flex;justify-content:center;">
        <i>{novel_name} PDF, {author_name} Short Stories, پلک جھپکتے قصے, Urdu Novel Bank, {novel_name} Online Reading</i>
    </div>
</div>
"""

    # ✅ Exact Original Colab UI Format
    display(HTML(f"""
    <div style="border: 2px solid #ccc; padding: 20px; border-radius: 10px; background-color: #fcfcfc;">
        <h3 style="margin-top:0;">📄 Blogger Embed Code</h3>
        <textarea id="final_code" style="width:100%;height:250px;">{html_content}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)" style="margin-bottom:15px; cursor:pointer;">📋 Copy Embed Code</button>

        <h3>🏷️ Blogger Labels (Tags)</h3>
        <textarea id="labels_code" style="width:100%;height:60px;">{', '.join(labels)}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('labels_code').value)" style="margin-bottom:15px; cursor:pointer;">📋 Copy Labels</button>

        <h3>📝 SEO Description (Meta Description)</h3>
        <textarea id="description_code" style="width:100%;height:60px;">{description}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('description_code').value)" style="cursor:pointer;">📋 Copy Description</button>
    </div>
    """))

# ✅ Usage (Yahan apna data dalein)
drive_link = "https://drive.google.com/file/d/1XYZabc987654321/view?usp=drive_link"
novel_title = "Bus Ulfat Si Ho Gai Hai Novel By Mahira Zainab Khan"

generate_palk_jhapaktay_post(drive_link, novel_title)
# Out:
#     <div style="border: 2px solid #ccc; padding: 20px; border-radius: 10px; background-color: #fcfcfc;">
#         <h3 style="margin-top:0;">📄 Blogger Embed Code</h3>
#         <textarea id="final_code" style="width:100%;height:250px;"><h1 style="text-align: center;">Bus Ulfat Si Ho Gai Hai Novel By Mahira Zainab Khan – پلک جھپکتے قصے</h1>
# <div>
#
# <div dir="rtl" style="text-align: right;">
# <p><span style="font-family: Arial, sans-serif;">
# <b>✨ پلک جھپکتے قصے ✨</b>
# <br><br>
# <b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔ یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
# </span></p>
#
# <p><span style="font-family: Arial, sans-serif;">
# اس سیگمنٹ میں شامل کہانیاں آپ <b>35 سے 40 منٹ</b> میں آسانی سے مکمل کر سکتے ہیں، مگر ان کا اثر دیر تک دل میں رہتا ہے۔ ہر کہانی الگ موضوع پر ہے اور اپنے اندر ایک خاص احساس سموئے ہوئے ہے۔
# </span></p>
#
# ...

# %%
import re
from IPython.display import HTML, display

def generate_palk_jhapaktay_qissay(drive_url, novel_title):
    # ✅ Extract Google Drive file ID
    if "id=" in drive_url:
        file_id = drive_url.split("id=")[-1].split("&")[0]
    elif "file/d/" in drive_url:
        file_id = drive_url.split("file/d/")[1].split("/")[0]
    else:
        raise ValueError("Invalid Google Drive link")

    preview_url = f"https://drive.google.com/file/d/{file_id}/preview"
    download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

    # ✅ Extract author name
    match = re.search(r"(.+?)\s+By\s+(.+)", novel_title, re.IGNORECASE)
    if match:
        novel_name = match.group(1).strip()
        author_name = match.group(2).strip()
    else:
        novel_name = novel_title
        author_name = "Famous Urdu Writer"

    # ✅ SEO Metadata for the Segment
    labels = [f"پلک جھپکتے قصے", f"{author_name} Novels", "Short Urdu Stories", "35 Minute Reads"]
    description = f"Read or download {novel_name} by {author_name} under our special segment 'Palk Jhapaktay Kissay'. Heart-touching short Urdu stories in PDF."

    # ✅ Customized Content for "Palk Jhapaktay Kissay"
    long_description = f"""
<div style="text-align: right; direction: rtl; font-family: 'Noto Nastaliq Urdu', 'Arial', sans-serif;">
<p><b>✨ پلک جھپکتے قصے ✨</b></p>
<p>
<b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔ یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
</p>
<p>
آج کی ہماری تحریر <b>"{novel_name}"</b> جسے <b>{author_name}</b> نے لکھا ہے، اسی سیگمنٹ کا حصہ ہے۔ اس کہانی کو آپ 35 سے 40 منٹ میں آسانی سے مکمل کر سکتے ہیں، مگر اس کا اثر دیر تک آپ کے دل میں رہے گا۔
</p>
<p>
یہ سیگمنٹ اُن لوگوں کے لیے ہے جو مصروف زندگی کے باوجود کہانیوں سے جڑے رہنا چاہتے ہیں۔ <b>آپ کے 40 منٹ، ایک خوبصورت کہانی کے لیے!</b>
</p>
</div>
<br>
"""

    # ✅ HTML Layout for Blogger
    html_content = f"""<h1 style="text-align: center;">{novel_name} By {author_name} – پلک جھپکتے قصے</h1>
<div style="border: 1px solid #ddd; padding: 15px; border-radius: 10px; background-color: #f9f9f9;">
    {long_description}

    <h2 style="border-bottom: 2px solid #eee; padding-bottom: 5px;"><i>Quick Overview</i></h2>
    <ul style="list-style-type: none; padding: 0;">
        <li><b>📖 Novel:</b> {novel_name}</li>
        <li><b>✍️ Writer:</b> {author_name}</li>
        <li><b>⏱️ Reading Time:</b> 35-40 Minutes</li>
        <li><b>📂 Category:</b> پلک جھپکتے قصے (Short Stories)</li>
    </ul>
</div>

<br>
<h2 style="text-align: center;"><i>Read Online Below</i></h2>
<div style="display:flex; justify-content:center; margin-bottom: 20px;">
    <iframe loading="lazy" style="width:100%; max-width:700px; height:500px; border: 2px solid #ccc; border-radius: 8px;" src="{preview_url}"></iframe>
</div>

<div style="text-align: center; margin-top: 20px;">
    <a href="{download_url}" style="background-color: #e91e63; color: white; padding: 12px 25px; text-decoration: none; font-weight: bold; border-radius: 5px; box-shadow: 0 4px 6px rgba(0,0,0,0.1);" target="_blank">Download PDF Version</a>
</div>

<br><br>
<div style="text-align: center; font-style: italic; color: #777;">
    Tags: {novel_name} PDF, {author_name} Stories, Palk Jhapaktay Kissay, Short Urdu Novels Online
</div>
"""

    # ✅ Colab UI
    display(HTML(f"""
    <div style="padding: 20px; border: 2px solid #4CAF50; border-radius: 10px;">
        <h2 style="color: #4CAF50;">✅ Post Ready For: {novel_name}</h2>

        <h3>📄 Blogger HTML Code (Copy this into HTML View)</h3>
        <textarea id="final_code" style="width:100%;height:200px; border: 1px solid #ccc;">{html_content}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('final_code').value)" style="padding: 10px; background: #4CAF50; color: white; border: none; cursor: pointer;">📋 Copy HTML Code</button>

        <h3>🏷️ Blogger Labels</h3>
        <textarea id="labels_code" style="width:100%;height:50px; border: 1px solid #ccc;">{', '.join(labels)}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('labels_code').value)" style="padding: 10px; background: #2196F3; color: white; border: none; cursor: pointer;">📋 Copy Labels</button>

        <h3>📝 Meta Description</h3>
        <textarea id="description_code" style="width:100%;height:50px; border: 1px solid #ccc;">{description}</textarea>
        <button onclick="navigator.clipboard.writeText(document.getElementById('description_code').value)" style="padding: 10px; background: #FF9800; color: white; border: none; cursor: pointer;">📋 Copy Description</button>
    </div>
    """))

# ==========================================
# 🚀 استعمال کا طریقہ (Usage)
# ==========================================
# یہاں اپنا ڈیٹا ڈالیں:
drive_link = "https://drive.google.com/file/d/1XYZabc987654321/view?usp=drive_link"
novel_title = "Bus Ulfat Si Ho Gai Hai Novel By Mahira Zainab Khan"

generate_palk_jhapaktay_qissay(drive_link, novel_title)
# Out:
#     <div style="padding: 20px; border: 2px solid #4CAF50; border-radius: 10px;">
#         <h2 style="color: #4CAF50;">✅ Post Ready For: Bus Ulfat Si Ho Gai Hai Novel</h2>
#
#         <h3>📄 Blogger HTML Code (Copy this into HTML View)</h3>
#         <textarea id="final_code" style="width:100%;height:200px; border: 1px solid #ccc;"><h1 style="text-align: center;">Bus Ulfat Si Ho Gai Hai Novel By Mahira Zainab Khan – پلک جھپکتے قصے</h1>
# <div style="border: 1px solid #ddd; padding: 15px; border-radius: 10px; background-color: #f9f9f9;">
#
# <div style="text-align: right; direction: rtl; font-family: 'Noto Nastaliq Urdu', 'Arial', sans-serif;">
# <p><b>✨ پلک جھپکتے قصے ✨</b></p>
# <p>
# <b>پلک جھپکتے قصے</b> ایک خاص سیگمنٹ ہے، جہاں آپ کو مختصر مگر دل کو چھو لینے والی کہانیاں پڑھنے کو ملتی ہیں۔ یہ کہانیاں اُن قارئین کے لیے ہیں جو کم وقت میں اچھی اور معنی خیز تحریریں پڑھنا چاہتے ہیں۔
# </p>
# <p>
# ...
